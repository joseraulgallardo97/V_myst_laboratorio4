# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;"
# src="https://www.carrerasenlinea.mx/logos/original/logo-instituto-tecnologico-y-de-estudios
# -superiores-de-occidente.png" width="150px" height="100px" />
#
#
# # MICROESTRUCTURAS Y SISTEMAS DE "TRADING"
# # LABORATORIO 4
#
# ## Nombres:
#
# ## Fecha:
#
# El propósito: Que puedas describir los efectos cuantitativos en el precio durante los comunicados de indicadores macroeconómicos, así como el detectar oportunidades de inversión a partir de los resultados obtenidos. Lo anterior, utilizando lo que se conoce como "Calendario Económico", y más en particular, aquel que incorpora información de las principales economías del mundo por lo que es ampliamiente utilizado en el mercado de Forex.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importando datos

# %%
data = pd.read_csv('../V_myst_laboratorio4/calendario_economico.csv',header=0, index_col=None, parse_dates=False)
data.head()
# Out:
#              timestamp Currency                         Name  \
# 0  01/05/2009 09:30:00      EUR   Sentix Investor Confidence
# 1  01/05/2009 15:00:00      USD  Construction Spending (MoM)
# 2  01/06/2009 08:55:00      EUR          Markit Services PMI
# 3  01/06/2009 09:00:00      EUR          Markit Services PMI
# 4  01/06/2009 10:00:00      EUR   Consumer Price Index (YoY)
#
#                    Country  Volatility  actual  previous  consensus
# 0  European Monetary Union           1   -34.4     -42.3        NaN
# 1            United States           1    -1.2      -0.4       -1.3
# 2                  Germany           1    46.6      46.4       46.4
# 3  European Monetary Union           0    42.1      42.0       42.0
# 4  European Monetary Union           2     1.6       2.1        1.8

# %% [markdown]
# ## Selección de indicadores

# %%
df = data[((data['Country'] == "United States") |  (data['Country'] == "European Monetary Union")) 
     & ((data['Name'] == "Factory Orders (MoM)") | (data['Name'] == "Industrial Production s.a. (MoM)"))].reset_index()
df.head()
# Out:
#    index            timestamp Currency                              Name  \
# 0      7  01/06/2009 15:00:00      USD              Factory Orders (MoM)
# 1     50  01/14/2009 10:00:00      EUR  Industrial Production s.a. (MoM)
# 2    174  02/05/2009 15:00:00      USD              Factory Orders (MoM)
# 3    195  02/12/2009 10:00:00      EUR  Industrial Production s.a. (MoM)
# 4    326  03/05/2009 15:00:00      USD              Factory Orders (MoM)
#
#                    Country  Volatility  actual  previous  consensus
# 0            United States           2    -6.5      -6.0       -2.3
# 1  European Monetary Union           1    -3.0      -1.2       -1.8
# 2            United States           2    -4.9      -6.5       -3.0
# 3  European Monetary Union           1    -4.5      -3.0       -2.5
# 4            United States           2    -3.5      -4.9       -2.0
